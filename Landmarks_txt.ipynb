# %% [markdown]
# # Load landmarks

# %%
import os

# %%
# 22 cases in total

with open(r'Landmarks/Case1-MRI-beforeUS.txt') as L1_b:
    L1 = L1_b.readlines()[5:]
    
with open(r'Landmarks/Case2-MRI-beforeUS.txt') as L2_b:
    L2 = L2_b.readlines()[5:]
    
with open(r'Landmarks/Case3-MRI-beforeUS.txt') as L3_b:
    L3 = L3_b.readlines()[5:]
    
with open(r'Landmarks/Case4-MRI-beforeUS.txt') as L4_b:
    L4 = L4_b.readlines()[5:]
    
with open(r'Landmarks/Case5-MRI-beforeUS.txt') as L5_b:
    L5 = L5_b.readlines()[5:]
    
with open(r'Landmarks/Case6-MRI-beforeUS.txt') as L6_b:
    L6 = L6_b.readlines()[5:]
    
with open(r'Landmarks/Case7-MRI-beforeUS.txt') as L7_b:
    L7 = L7_b.readlines()[5:]
    
with open(r'Landmarks/Case8-MRI-beforeUS.txt') as L8_b:
    L8 = L8_b.readlines()[5:]
    
with open(r'Landmarks/Case12-MRI-beforeUS.txt') as L12_b:
    L12 = L12_b.readlines()[5:]
    
with open(r'Landmarks/Case13-MRI-beforeUS.txt') as L13_b:
    L13 = L13_b.readlines()[5:]
    
with open(r'Landmarks/Case14-MRI-beforeUS.txt') as L14_b:
    L14 = L14_b.readlines()[5:]
    
with open(r'Landmarks/Case15-MRI-beforeUS.txt') as L15_b:
    L15 = L15_b.readlines()[5:]
    
with open(r'Landmarks/Case16-MRI-beforeUS.txt') as L16_b:
    L16 = L16_b.readlines()[5:]
    
with open(r'Landmarks/Case17-MRI-beforeUS.txt') as L17_b:
    L17 = L17_b.readlines()[5:]
    
with open(r'Landmarks/Case18-MRI-beforeUS.txt') as L18_b:
    L18 = L18_b.readlines()[5:]
    
with open(r'Landmarks/Case19-MRI-beforeUS.txt') as L19_b:
    L19 = L19_b.readlines()[5:]
    
with open(r'Landmarks/Case21-MRI-beforeUS.txt') as L21_b:
    L21 = L21_b.readlines()[5:]
    
with open(r'Landmarks/Case23-MRI-beforeUS.txt') as L23_b:
    L23 = L23_b.readlines()[5:]
    
with open(r'Landmarks/Case24-MRI-beforeUS.txt') as L24_b:
    L24 = L24_b.readlines()[5:]
    
with open(r'Landmarks/Case25-MRI-beforeUS.txt') as L25_b:
    L25 = L25_b.readlines()[5:]
    
with open(r'Landmarks/Case26-MRI-beforeUS.txt') as L26_b:
    L26 = L26_b.readlines()[5:]
    
with open(r'Landmarks/Case27-MRI-beforeUS.txt') as L27_b:
    L27 = L27_b.readlines()[5:]

# %% [markdown]
# # Convert into dataframes

# %%
import pandas as pd
import numpy as np

# %%
L1_df = pd.DataFrame(L1, columns=['coordinates'])
# make string version of original column, call it 'coord'
L1_df['coord'] = L1_df['coordinates'].astype(str)
#Split dataframe into columns
L1_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L1_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L1_df.drop('coord', axis=1, inplace=True)
L1_df.drop('coordinates', axis=1, inplace=True)
L1_df.drop('extra', axis=1, inplace=True)
L1_df.drop('null', axis=1, inplace=True)

# %%
L2_df = pd.DataFrame(L2, columns=['coordinates'])
# make string version of original column, call it 'col'
L2_df['coord'] = L2_df['coordinates'].astype(str)
#Split dataframe into columns
L2_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L2_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L2_df.drop('coord', axis=1, inplace=True)
L2_df.drop('coordinates', axis=1, inplace=True)
L2_df.drop('extra', axis=1, inplace=True)
L2_df.drop('null', axis=1, inplace=True)

# %%
L3_df = pd.DataFrame(L3, columns=['coordinates'])
# make string version of original column, call it 'col'
L3_df['coord'] = L3_df['coordinates'].astype(str)
#Split dataframe into columns
L3_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L3_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L3_df.drop('coord', axis=1, inplace=True)
L3_df.drop('coordinates', axis=1, inplace=True)
L3_df.drop('extra', axis=1, inplace=True)
L3_df.drop('null', axis=1, inplace=True)

# %%
L4_df = pd.DataFrame(L4, columns=['coordinates'])
# make string version of original column, call it 'col'
L4_df['coord'] = L4_df['coordinates'].astype(str)
#Split dataframe into columns
L4_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L4_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L4_df.drop('coord', axis=1, inplace=True)
L4_df.drop('coordinates', axis=1, inplace=True)
L4_df.drop('extra', axis=1, inplace=True)
L4_df.drop('null', axis=1, inplace=True)

# %%
L5_df = pd.DataFrame(L5, columns=['coordinates'])
# make string version of original column, call it 'col'
L5_df['coord'] = L5_df['coordinates'].astype(str)
#Split dataframe into columns
L5_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L5_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L5_df.drop('coord', axis=1, inplace=True)
L5_df.drop('coordinates', axis=1, inplace=True)
L5_df.drop('extra', axis=1, inplace=True)
L5_df.drop('null', axis=1, inplace=True)

# %%
L6_df = pd.DataFrame(L6, columns=['coordinates'])
# make string version of original column, call it 'col'
L6_df['coord'] = L6_df['coordinates'].astype(str)
#Split dataframe into columns
L6_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L6_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L6_df.drop('coord', axis=1, inplace=True)
L6_df.drop('coordinates', axis=1, inplace=True)
L6_df.drop('extra', axis=1, inplace=True)
L6_df.drop('null', axis=1, inplace=True)

# %%
L7_df = pd.DataFrame(L7, columns=['coordinates'])
# make string version of original column, call it 'col'
L7_df['coord'] = L7_df['coordinates'].astype(str)
#Split dataframe into columns
L7_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L7_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L7_df.drop('coord', axis=1, inplace=True)
L7_df.drop('coordinates', axis=1, inplace=True)
L7_df.drop('extra', axis=1, inplace=True)
L7_df.drop('null', axis=1, inplace=True)

# %%
L8_df = pd.DataFrame(L8, columns=['coordinates'])
# make string version of original column, call it 'col'
L8_df['coord'] = L8_df['coordinates'].astype(str)
#Split dataframe into columns
L8_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L8_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L8_df.drop('coord', axis=1, inplace=True)
L8_df.drop('coordinates', axis=1, inplace=True)
L8_df.drop('extra', axis=1, inplace=True)
L8_df.drop('null', axis=1, inplace=True)

# %%
L12_df = pd.DataFrame(L12, columns=['coordinates'])
# make string version of original column, call it 'col'
L12_df['coord'] = L12_df['coordinates'].astype(str)
#Split dataframe into columns
L12_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L12_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L12_df.drop('coord', axis=1, inplace=True)
L12_df.drop('coordinates', axis=1, inplace=True)
L12_df.drop('extra', axis=1, inplace=True)
L12_df.drop('null', axis=1, inplace=True)

# %%
L13_df = pd.DataFrame(L13, columns=['coordinates'])
# make string version of original column, call it 'col'
L13_df['coord'] = L13_df['coordinates'].astype(str)
#Split dataframe into columns
L13_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L13_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L13_df.drop('coord', axis=1, inplace=True)
L13_df.drop('coordinates', axis=1, inplace=True)
L13_df.drop('extra', axis=1, inplace=True)
L13_df.drop('null', axis=1, inplace=True)

# %%
L14_df = pd.DataFrame(L14, columns=['coordinates'])
# make string version of original column, call it 'col'
L14_df['coord'] = L14_df['coordinates'].astype(str)
#Split dataframe into columns
L14_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L14_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L14_df.drop('coord', axis=1, inplace=True)
L14_df.drop('coordinates', axis=1, inplace=True)
L14_df.drop('extra', axis=1, inplace=True)
L14_df.drop('null', axis=1, inplace=True)

# %%
L15_df = pd.DataFrame(L15, columns=['coordinates'])
# make string version of original column, call it 'col'
L15_df['coord'] = L15_df['coordinates'].astype(str)
#Split dataframe into columns
L15_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L15_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L15_df.drop('coord', axis=1, inplace=True)
L15_df.drop('coordinates', axis=1, inplace=True)
L15_df.drop('extra', axis=1, inplace=True)
L15_df.drop('null', axis=1, inplace=True)

# %%
L16_df = pd.DataFrame(L16, columns=['coordinates'])
# make string version of original column, call it 'col'
L16_df['coord'] = L16_df['coordinates'].astype(str)
#Split dataframe into columns
L16_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L16_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L16_df.drop('coord', axis=1, inplace=True)
L16_df.drop('coordinates', axis=1, inplace=True)
L16_df.drop('extra', axis=1, inplace=True)
L16_df.drop('null', axis=1, inplace=True)

# %%
L17_df = pd.DataFrame(L17, columns=['coordinates'])
# make string version of original column, call it 'col'
L17_df['coord'] = L17_df['coordinates'].astype(str)
#Split dataframe into columns
L17_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L17_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L17_df.drop('coord', axis=1, inplace=True)
L17_df.drop('coordinates', axis=1, inplace=True)
L17_df.drop('extra', axis=1, inplace=True)
L17_df.drop('null', axis=1, inplace=True)

# %%
L18_df = pd.DataFrame(L18, columns=['coordinates'])
# make string version of original column, call it 'col'
L18_df['coord'] = L18_df['coordinates'].astype(str)
#Split dataframe into columns
L18_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L18_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L18_df.drop('coord', axis=1, inplace=True)
L18_df.drop('coordinates', axis=1, inplace=True)
L18_df.drop('extra', axis=1, inplace=True)
L18_df.drop('null', axis=1, inplace=True)

# %%
L19_df = pd.DataFrame(L19, columns=['coordinates'])
# make string version of original column, call it 'col'
L19_df['coord'] = L19_df['coordinates'].astype(str)
#Split dataframe into columns
L19_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L19_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L19_df.drop('coord', axis=1, inplace=True)
L19_df.drop('coordinates', axis=1, inplace=True)
L19_df.drop('extra', axis=1, inplace=True)
L19_df.drop('null', axis=1, inplace=True)

# %%
L21_df = pd.DataFrame(L21, columns=['coordinates'])
# make string version of original column, call it 'col'
L21_df['coord'] = L21_df['coordinates'].astype(str)
#Split dataframe into columns
L21_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L21_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L21_df.drop('coord', axis=1, inplace=True)
L21_df.drop('coordinates', axis=1, inplace=True)
L21_df.drop('extra', axis=1, inplace=True)
L21_df.drop('null', axis=1, inplace=True)

# %%
L23_df = pd.DataFrame(L23, columns=['coordinates'])
# make string version of original column, call it 'col'
L23_df['coord'] = L23_df['coordinates'].astype(str)
#Split dataframe into columns
L23_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L23_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L23_df.drop('coord', axis=1, inplace=True)
L23_df.drop('coordinates', axis=1, inplace=True)
L23_df.drop('extra', axis=1, inplace=True)
L23_df.drop('null', axis=1, inplace=True)

# %%
L24_df = pd.DataFrame(L24, columns=['coordinates'])
# make string version of original column, call it 'col'
L24_df['coord'] = L24_df['coordinates'].astype(str)
#Split dataframe into columns
L24_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L24_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L24_df.drop('coord', axis=1, inplace=True)
L24_df.drop('coordinates', axis=1, inplace=True)
L24_df.drop('extra', axis=1, inplace=True)
L24_df.drop('null', axis=1, inplace=True)

# %%
L25_df = pd.DataFrame(L25, columns=['coordinates'])
# make string version of original column, call it 'col'
L25_df['coord'] = L25_df['coordinates'].astype(str)
#Split dataframe into columns
L25_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L25_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L25_df.drop('coord', axis=1, inplace=True)
L25_df.drop('coordinates', axis=1, inplace=True)
L25_df.drop('extra', axis=1, inplace=True)
L25_df.drop('null', axis=1, inplace=True)

# %%
L26_df = pd.DataFrame(L26, columns=['coordinates'])
# make string version of original column, call it 'col'
L26_df['coord'] = L26_df['coordinates'].astype(str)
#Split dataframe into columns
L26_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L26_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L26_df.drop('coord', axis=1, inplace=True)
L26_df.drop('coordinates', axis=1, inplace=True)
L26_df.drop('extra', axis=1, inplace=True)
L26_df.drop('null', axis=1, inplace=True)

# %%
L27_df = pd.DataFrame(L27, columns=['coordinates'])
# make string version of original column, call it 'col'
L27_df['coord'] = L27_df['coordinates'].astype(str)
#Split dataframe into columns
L27_df[['null','MRI_x','MRI_y','MRI_z','US_x','US_y','US_z','extra']] = L27_df.coord.str.split(' ',expand=True)
# get rid of the extra variables
L27_df.drop('coord', axis=1, inplace=True)
L27_df.drop('coordinates', axis=1, inplace=True)
L27_df.drop('extra', axis=1, inplace=True)
L27_df.drop('null', axis=1, inplace=True)

# %% [markdown]
# # Save landmark files

# %% [markdown]
# ## Inputs for Transformix (US Landmarks)

# %%
# Saving values
np.savetxt(r'Landmarks\US_before\Case1_US.txt', L1_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case2_US.txt', L2_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case3_US.txt', L3_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case4_US.txt', L4_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case5_US.txt', L5_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case6_US.txt', L6_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case7_US.txt', L7_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case8_US.txt', L8_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case12_US.txt', L12_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case13_US.txt', L13_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case14_US.txt', L14_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case15_US.txt', L15_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case16_US.txt', L16_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case17_US.txt', L17_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case18_US.txt', L18_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case19_US.txt', L19_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case21_US.txt', L21_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case23_US.txt', L23_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case24_US.txt', L24_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case25_US.txt', L25_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case26_US.txt', L26_df.values[:,3:6], fmt='%s')
np.savetxt(r'Landmarks\US_before\Case27_US.txt', L27_df.values[:,3:6], fmt='%s')

# %%
#Adding the two first lines
f1 = open(r'Landmarks\US_before\Case1\inputPoints.txt','w')
f1.write('point\n')
f1.write('15 \n')
f1.write(open(r'Landmarks\US_before\Case1_US.txt').read())
f1.close()

f2 = open(r'Landmarks\US_before\Case2\inputPoints.txt','w')
f2.write('point\n')
f2.write('15 \n')
f2.write(open(r'Landmarks\US_before\Case2_US.txt').read())
f2.close()

f3 = open(r'Landmarks\US_before\Case3\inputPoints.txt','w')
f3.write('point\n')
f3.write('15 \n')
f3.write(open(r'Landmarks\US_before\Case3_US.txt').read())
f3.close()

f4 = open(r'Landmarks\US_before\Case4\inputPoints.txt','w')
f4.write('point\n')
f4.write('15 \n')
f4.write(open(r'Landmarks\US_before\Case4_US.txt').read())
f4.close()

f5 = open(r'Landmarks\US_before\Case5\inputPoints.txt','w')
f5.write('point\n')
f5.write('15 \n')
f5.write(open(r'Landmarks\US_before\Case5_US.txt').read())
f5.close()

f6 = open(r'Landmarks\US_before\Case6\inputPoints.txt','w')
f6.write('point\n')
f6.write('15 \n')
f6.write(open(r'Landmarks\US_before\Case6_US.txt').read())
f6.close()

f7 = open(r'Landmarks\US_before\Case7\inputPoints.txt','w')
f7.write('point\n')
f7.write('15 \n')
f7.write(open(r'Landmarks\US_before\Case7_US.txt').read())
f7.close()

f8 = open(r'Landmarks\US_before\Case8\inputPoints.txt','w')
f8.write('point\n')
f8.write('15 \n')
f8.write(open(r'Landmarks\US_before\Case8_US.txt').read())
f8.close()

f12 = open(r'Landmarks\US_before\Case12\inputPoints.txt','w')
f12.write('point\n')
f12.write('16 \n')
f12.write(open(r'Landmarks\US_before\Case12_US.txt').read())
f12.close()

f13 = open(r'Landmarks\US_before\Case13\inputPoints.txt','w')
f13.write('point\n')
f13.write('15 \n')
f13.write(open(r'Landmarks\US_before\Case13_US.txt').read())
f13.close()

f14 = open(r'Landmarks\US_before\Case14\inputPoints.txt','w')
f14.write('point\n')
f14.write('15 \n')
f14.write(open(r'Landmarks\US_before\Case14_US.txt').read())
f14.close()

f15 = open(r'Landmarks\US_before\Case15\inputPoints.txt','w')
f15.write('point\n')
f15.write('15 \n')
f15.write(open(r'Landmarks\US_before\Case15_US.txt').read())
f15.close()

f16 = open(r'Landmarks\US_before\Case16\inputPoints.txt','w')
f16.write('point\n')
f16.write('15 \n')
f16.write(open(r'Landmarks\US_before\Case16_US.txt').read())
f16.close()

f17 = open(r'Landmarks\US_before\Case17\inputPoints.txt','w')
f17.write('point\n')
f17.write('16 \n')
f17.write(open(r'Landmarks\US_before\Case17_US.txt').read())
f17.close()

f18 = open(r'Landmarks\US_before\Case18\inputPoints.txt','w')
f18.write('point\n')
f18.write('16 \n')
f18.write(open(r'Landmarks\US_before\Case18_US.txt').read())
f18.close()

f19 = open(r'Landmarks\US_before\Case19\inputPoints.txt','w')
f19.write('point\n')
f19.write('16 \n')
f19.write(open(r'Landmarks\US_before\Case19_US.txt').read())
f19.close()

f21 = open(r'Landmarks\US_before\Case21\inputPoints.txt','w')
f21.write('point\n')
f21.write('16 \n')
f21.write(open(r'Landmarks\US_before\Case21_US.txt').read())
f21.close()

f23 = open(r'Landmarks\US_before\Case23\inputPoints.txt','w')
f23.write('point\n')
f23.write('15 \n')
f23.write(open(r'Landmarks\US_before\Case23_US.txt').read())
f23.close()

f24 = open(r'Landmarks\US_before\Case24\inputPoints.txt','w')
f24.write('point\n')
f24.write('16 \n')
f24.write(open(r'Landmarks\US_before\Case24_US.txt').read())
f24.close()

f25 = open(r'Landmarks\US_before\Case25\inputPoints.txt','w')
f25.write('point\n')
f25.write('15 \n')
f25.write(open(r'Landmarks\US_before\Case25_US.txt').read())
f25.close()

f26 = open(r'Landmarks\US_before\Case26\inputPoints.txt','w')
f26.write('point\n')
f26.write('16 \n')
f26.write(open(r'Landmarks\US_before\Case26_US.txt').read())
f26.close()

f27 = open(r'Landmarks\US_before\Case27\inputPoints.txt','w')
f27.write('point\n')
f27.write('16 \n')
f27.write(open(r'Landmarks\US_before\Case27_US.txt').read())
f27.close()

# %% [markdown]
# ## MRI Landmarks

# %%
# Saving values
np.savetxt(r'Landmarks\MRI\Case1_MRI.txt', L1_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case2_MRI.txt', L2_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case3_MRI.txt', L3_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case4_MRI.txt', L4_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case5_MRI.txt', L5_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case6_MRI.txt', L6_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case7_MRI.txt', L7_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case8_MRI.txt', L8_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case12_MRI.txt', L12_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case13_MRI.txt', L13_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case14_MRI.txt', L14_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case15_MRI.txt', L15_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case16_MRI.txt', L16_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case17_MRI.txt', L17_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case18_MRI.txt', L18_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case19_MRI.txt', L19_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case21_MRI.txt', L21_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case23_MRI.txt', L23_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case24_MRI.txt', L24_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case25_MRI.txt', L25_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case26_MRI.txt', L26_df.values[:,0:3], fmt='%s')
np.savetxt(r'Landmarks\MRI\Case27_MRI.txt', L27_df.values[:,0:3], fmt='%s')
